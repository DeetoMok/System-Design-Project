# %%
trainingOHCA_fileName = "generatedPoints1_100000_subzone.csv"
candidateAED_fileName = "buildings_locations_subzone.csv"

# %%
import pandas as pd
import numpy as np
from haversine import haversine_vector, Unit
from haversine import haversine
from os import path
import scipy.sparse
import gurobipy as gp
from gurobipy import GRB
from gurobipy import quicksum
from pulp import *
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt     
import seaborn as sns
from itertools import combinations
from sklearn import preprocessing, cluster
from sklearn.metrics import silhouette_score
import scipy
import scipy.cluster
from matplotlib import colors as mcolors
from skimage.io import imread
import math
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import NearestCentroid
from numpy import unique
from numpy import where
from sklearn.datasets import make_classification
import time

# %%
def MCLP(S,OHCA_Cluster,AED_Cluster,d,P): #Input for MCLP to return the coordinates of AEDs to be placed
    
    # S is Distance beyond which is considered uncovered
    # P is the number of AEDs to be placed in that cluster 
    
    I = OHCA_Cluster.index.values.tolist() #Demand Node
    J = AED_Cluster.index.values.tolist() #Facility Node
    P = P
    #a = np.ones(len(OHCA_Cluster))
    
    # N is a list in which each item is a list of nodes within threshold distance of ith node
    N = [[j for j in J if d[i][j] < S] for i in I]
    #P = 2400 #Number of AEDs to be placed in this cluster
    
    #Optimization
    prob = LpProblem("MCLP",LpMaximize)
    x = LpVariable.dicts("x",J,0,1,cat="Integer")
    y = LpVariable.dicts("y",I,0,1,cat="Integer")
    #a = LpVariable.dicts("a",I,cat="Continuous")
    
    #Objective
    #prob += lpSum([a[i]*y[i] for i in I])
    prob += lpSum([y[i] for i in I])
    
    #Constraints
    for i in I:
        prob += lpSum([x[j] for j in N[i]]) >= y[i]
       # for j in N[i]:
            #if x[j] == 1:
                #prob += a[i] == 0.549*d[i][j]**-0.584
        #a[i] = [0.549*d[i][j]**-0.584 for j in N[i] if x[j] == 1]
        
    prob +=lpSum([x[j] for j in J]) == P

    #Solving
    #solver = getSolver('GUROBI')
    #prob.solve(solver)
    prob.solve(GUROBI(msg=0))
    
    x_soln = np.array([x[j].varValue for j in J])
    print ("OHCA Served is = ", value(prob.objective))
    AED_Chosen = pd.concat([AED_Cluster,pd.DataFrame(x_soln,columns=['x'])],axis=1)
    AED_Chosen = AED_Chosen[AED_Chosen['x'] == 1]
    AED_Chosen = AED_Chosen.drop(columns=['x'])
    return(AED_Chosen)

# %%
def kmeans_OHCA_AED(OHCA,AED,k=2): #k is the number of clusters chosen
    kmeans = KMeans(n_clusters = k, random_state = 0).fit(OHCA)
    
    OHCA_Cluster_All = pd.concat([OHCA,pd.DataFrame(kmeans.labels_,columns = ["cluster"])],axis=1)
    AED_lable = kmeans.predict(AED)

    AED_Cluster_All = pd.concat([AED, pd.DataFrame(AED_lable,columns = ["cluster"])], axis=1)

    return OHCA_Cluster_All, AED_Cluster_All

# %%
# input: two clusters 
# output: All_AED_in_Cluster
def MCLP_in_Cluster(OHCA1,candidateAED1,p_subzone,k=2):
    OHCA1_clusters, candidateAED1_clusters = kmeans_OHCA_AED(OHCA1, candidateAED1,k)
    All_AED_in_Cluster=pd.DataFrame(columns=['LatAED', 'LongAED']) 
    for i in range(k):
        OHCA20a = OHCA1_clusters[OHCA1_clusters['cluster']==i][["LatOHCA","LongOHCA"]].reset_index(drop=True)
        candidateAED20a = candidateAED1_clusters[candidateAED1_clusters['cluster']==i][["LatAED","LongAED"]].reset_index(drop=True)
        if len(candidateAED20a)>0:
            d1 = haverDist(OHCA20a,candidateAED20a)
            sub_AED_df = MCLP(100,OHCA20a,candidateAED20a,d1,int(p_subzone/k))
            All_AED_in_Cluster=All_AED_in_Cluster.append(sub_AED_df)
        else: pass
    return All_AED_in_Cluster

# %%
def kmeansPlot(OHCA_Cluster_All, k):
    colours = list(dict(mcolors.BASE_COLORS, **mcolors.CSS4_COLORS).keys())
    for i in range(k):
        plt.scatter(x=OHCA_Cluster_All[OHCA_Cluster_All["cluster"]==i].iloc[:,0], y= OHCA_Cluster_All[OHCA_Cluster_All["cluster"]==i].iloc[:,1], s=5, c=colours[i])

# %%
def haverDist(OHCA_Cluster,AED_Cluster):
    d = haversine_vector(list(zip(OHCA_Cluster.LatOHCA, OHCA_Cluster.LongOHCA)), list(zip(AED_Cluster.LatAED, AED_Cluster.LongAED)), Unit.METERS, comb=True).T
    return(d)

# %%
OHCA = pd.read_csv(trainingOHCA_fileName)
candidateAED = pd.read_csv(candidateAED_fileName)

P_count=OHCA['region'].value_counts()
len(P_count)
# Out:
# 327

# %%
P_count
# Out:
# 300    1966
# 273    1960
# 179    1646
# 105    1435
# 141    1428
#        ...
# 153      18
# 69       16
# 323      14
# 4         2
# 259       1
# Name: region, Length: 327, dtype: int64

# %%
# %%time

start_time = time.time()

ALL_AED= pd.DataFrame(columns=['LatAED', 'LongAED']) 
all_AED_num=9880
all_OHCA_num=97542

for subzone in range(1,333):

    if subzone not in (7, 8, 9,159,174,231, 239,259,283, 284, 287,301, 304, 305, 317, 323):
        p_subzone=int(P_count.at[subzone]*all_AED_num/all_OHCA_num)
        print(subzone, P_count.at[subzone], p_subzone )
        OHCA1=OHCA[OHCA['region']== subzone]
        OHCA1=OHCA1[['LatOHCA','LongOHCA']].reset_index(drop=True)
        candidateAED1 = candidateAED[candidateAED['region']==subzone].copy()
        candidateAED1 = candidateAED1[['LatAED','LongAED']].reset_index(drop=True)
        candidateAED1 = candidateAED1.apply(lambda x: pd.to_numeric(x, errors='coerce')).dropna()
        AED_sub =MCLP_in_Cluster(OHCA1,candidateAED1,p_subzone,2)
        ALL_AED=ALL_AED.append(AED_sub)
print("Time is --- %s seconds ---" % (time.time() - start_time))
# Out:
# 1 219 22
# OHCA Served is =  None
# OHCA Served is =  None
# 2 153 15
# OHCA Served is =  85.0
# OHCA Served is =  44.0
# 3 199 20
# OHCA Served is =  85.0
# OHCA Served is =  94.0
# 4 2 0
# OHCA Served is =  0.0
# OHCA Served is =  0.0
# 5 151 15
# OHCA Served is =  36.0
# OHCA Served is =  67.0
# 6 153 15
# OHCA Served is =  None
# OHCA Served is =  None
# 10 179 18
# OHCA Served is =  16.0
# OHCA Served is =  34.0
# 11 523 52
# OHCA Served is =  102.0
# OHCA Served is =  None
# 12 29 2
# OHCA Served is =  12.0
# OHCA Served is =  8.0
# 13 117 11
# OHCA Served is =  None
# OHCA Served is =  None
# 14 507 51
# OHCA Served is =  80.0
# OHCA Served is =  172.0
# 15 186 18
# OHCA Served is =  50.0
# OHCA Served is =  97.0
# 16 46 4
# OHCA Served is =  19.0
# OHCA Served is =  20.0
# 17 217 21
# OHCA Served is =  99.0
# OHCA Served is =  86.0
# 18 102 10
# OHCA Served is =  48.0
# OHCA Served is =  43.0
# 19 23 2
# OHCA Served is =  12.0
# OHCA Served is =  8.0
# 20 53 5
# OHCA Served is =  19.0
# OHCA Served is =  19.0
# 21 155 15
# OHCA Served is =  74.0
# OHCA Served is =  67.0
# 22 411 41
# OHCA Served is =  153.0
# OHCA Served is =  107.0
# 23 94 9
# OHCA Served is =  30.0
# OHCA Served is =  21.0
# 24 236 23
# OHCA Served is =  51.0
# OHCA Served is =  67.0
# 25 232 23
# OHCA Served is =  71.0
# OHCA Served is =  111.0
# 26 161 16
# OHCA Served is =  81.0
# OHCA Served is =  57.0
# 27 175 17
# OHCA Served is =  88.0
# OHCA Served is =  68.0
# 28 215 21
# OHCA Served is =  97.0
# OHCA Served is =  113.0
# 29 18 1
# OHCA Served is =  0.0
# OHCA Served is =  0.0
# 30 54 5
# OHCA Served is =  23.0
# OHCA Served is =  16.0
# 31 45 4
# OHCA Served is =  22.0
# OHCA Served is =  17.0
# 32 236 23
# OHCA Served is =  158.0
# OHCA Served is =  74.0
# 33 93 9
# OHCA Served is =  17.0
# OHCA Served is =  23.0
# 34 165 16
# OHCA Served is =  79.0
# OHCA Served is =  75.0
# 35 61 6
# OHCA Served is =  13.0
# OHCA Served is =  21.0
# 36 186 18
# OHCA Served is =  31.0
# OHCA Served is =  None
# 37 221 22
# OHCA Served is =  55.0
# OHCA Served is =  104.0
# 38 60 6
# OHCA Served is =  25.0
# OHCA Served is =  33.0
# 39 312 31
# OHCA Served is =  119.0
# OHCA Served is =  149.0
# 40 149 15
# OHCA Served is =  76.0
# OHCA Served is =  61.0
# 41 403 40
# OHCA Served is =  227.0
# OHCA Served is =  154.0
# 42 240 24
# OHCA Served is =  122.0
# OHCA Served is =  99.0
# 43 106 10
# OHCA Served is =  46.0
# OHCA Served is =  43.0
# 44 80 8
# OHCA Served is =  20.0
# OHCA Served is =  18.0
# 45 148 14
# OHCA Served is =  27.0
# OHCA Served is =  43.0
# 46 311 31
# OHCA Served is =  106.0
# OHCA Served is =  72.0
# 47 114 11
# OHCA Served is =  51.0
# OHCA Served is =  48.0
# 48 137 13
# OHCA Served is =  12.0
# OHCA Served is =  56.0
# 49 20 2
# OHCA Served is =  3.0
# OHCA Served is =  13.0
# 50 44 4
# OHCA Served is =  15.0
# OHCA Served is =  22.0
# 51 463 46
# OHCA Served is =  160.0
# OHCA Served is =  184.0
# 52 608 61
# OHCA Served is =  175.0
# OHCA Served is =  177.0
# 53 74 7
# OHCA Served is =  24.0
# OHCA Served is =  27.0
# 54 277 28
# OHCA Served is =  99.0
# OHCA Served is =  89.0
# 55 515 52
# OHCA Served is =  208.0
# OHCA Served is =  231.0
# 56 129 13
# OHCA Served is =  56.0
# OHCA Served is =  57.0
# 57 116 11
# OHCA Served is =  34.0
# OHCA Served is =  38.0
# 58 62 6
# OHCA Served is =  29.0
# OHCA Served is =  26.0
# 59 212 21
# OHCA Served is =  66.0
# OHCA Served is =  66.0
# 60 210 21
# OHCA Served is =  63.0
# OHCA Served is =  85.0
# 61 41 4
# OHCA Served is =  4.0
# OHCA Served is =  6.0
# 62 173 17
# OHCA Served is =  33.0
# OHCA Served is =  36.0
# 63 59 5
# OHCA Served is =  15.0
# OHCA Served is =  14.0
# 64 281 28
# OHCA Served is =  None
# OHCA Served is =  72.0
# 65 297 30
# OHCA Served is =  120.0
# OHCA Served is =  159.0
# 66 130 13
# OHCA Served is =  59.0
# OHCA Served is =  49.0
# 67 190 19
# OHCA Served is =  48.0
# OHCA Served is =  None
# 68 111 11
# OHCA Served is =  35.0
# OHCA Served is =  73.0
# 69 16 1
# OHCA Served is =  0.0
# OHCA Served is =  0.0
# 70 215 21
# OHCA Served is =  63.0
# OHCA Served is =  61.0
# 71 63 6
# OHCA Served is =  29.0
# OHCA Served is =  25.0
# 72 75 7
# OHCA Served is =  38.0
# OHCA Served is =  31.0
# 73 231 23
# OHCA Served is =  107.0
# OHCA Served is =  83.0
# 74 265 26
# OHCA Served is =  133.0
# OHCA Served is =  111.0
# 75 127 12
# OHCA Served is =  63.0
# OHCA Served is =  51.0
# 76 199 20
# OHCA Served is =  37.0
# OHCA Served is =  43.0
# 77 87 8
# OHCA Served is =  43.0
# OHCA Served is =  38.0
# 78 100 10
# OHCA Served is =  41.0
# OHCA Served is =  43.0
# 79 88 8
# OHCA Served is =  40.0
# OHCA Served is =  45.0
# 80 55 5
# OHCA Served is =  14.0
# OHCA Served is =  27.0
# 81 93 9
# OHCA Served is =  18.0
# OHCA Served is =  16.0
# 82 240 24
# OHCA Served is =  61.0
# OHCA Served is =  87.0
# 83 95 9
# OHCA Served is =  40.0
# OHCA Served is =  38.0
# 84 101 10
# OHCA Served is =  41.0
# OHCA Served is =  47.0
# 85 63 6
# OHCA Served is =  30.0
# OHCA Served is =  27.0
# 86 464 46
# OHCA Served is =  225.0
# OHCA Served is =  225.0
# 87 63 6
# OHCA Served is =  22.0
# OHCA Served is =  39.0
# 88 20 2
# OHCA Served is =  10.0
# OHCA Served is =  7.0
# 89 61 6
# OHCA Served is =  27.0
# OHCA Served is =  28.0
# 90 52 5
# OHCA Served is =  18.0
# OHCA Served is =  18.0
# 91 184 18
# OHCA Served is =  34.0
# OHCA Served is =  30.0
# 92 339 34
# OHCA Served is =  104.0
# OHCA Served is =  200.0
# 93 33 3
# OHCA Served is =  9.0
# OHCA Served is =  7.0
# 94 243 24
# OHCA Served is =  95.0
# OHCA Served is =  98.0
# 95 103 10
# OHCA Served is =  18.0
# OHCA Served is =  26.0
# 96 379 38
# OHCA Served is =  194.0
# OHCA Served is =  168.0
# 97 65 6
# OHCA Served is =  24.0
# OHCA Served is =  13.0
# 98 199 20
# OHCA Served is =  51.0
# OHCA Served is =  56.0
# 99 146 14
# OHCA Served is =  35.0
# OHCA Served is =  53.0
# 100 1030 104
# OHCA Served is =  492.0
# OHCA Served is =  526.0
# 101 104 10
# OHCA Served is =  27.0
# OHCA Served is =  34.0
# 102 157 15
# OHCA Served is =  53.0
# OHCA Served is =  47.0
# 103 509 51
# OHCA Served is =  264.0
# OHCA Served is =  224.0
# 104 151 15
# OHCA Served is =  33.0
# OHCA Served is =  79.0
# 105 1435 145
# OHCA Served is =  788.0
# OHCA Served is =  591.0
# 106 420 42
# OHCA Served is =  188.0
# OHCA Served is =  187.0
# 107 122 12
# OHCA Served is =  43.0
# OHCA Served is =  44.0
# 108 390 39
# OHCA Served is =  102.0
# OHCA Served is =  70.0
# 109 582 58
# OHCA Served is =  285.0
# OHCA Served is =  245.0
# 110 295 29
# OHCA Served is =  148.0
# OHCA Served is =  119.0
# 111 275 27
# OHCA Served is =  134.0
# OHCA Served is =  102.0
# 112 61 6
# OHCA Served is =  10.0
# OHCA Served is =  8.0
# 113 187 18
# OHCA Served is =  81.0
# OHCA Served is =  90.0
# 114 174 17
# OHCA Served is =  82.0
# OHCA Served is =  85.0
# 115 377 38
# OHCA Served is =  119.0
# OHCA Served is =  145.0
# 116 179 18
# OHCA Served is =  None
# OHCA Served is =  None
# 117 99 10
# OHCA Served is =  53.0
# OHCA Served is =  45.0
# 118 60 6
# OHCA Served is =  26.0
# OHCA Served is =  24.0
# 119 71 7
# OHCA Served is =  7.0
# OHCA Served is =  11.0
# 120 42 4
# OHCA Served is =  4.0
# OHCA Served is =  4.0
# 121 25 2
# OHCA Served is =  1.0
# OHCA Served is =  2.0
# 122 109 11
# OHCA Served is =  41.0
# OHCA Served is =  34.0
# 123 342 34
# OHCA Served is =  147.0
# OHCA Served is =  187.0
# 124 83 8
# OHCA Served is =  39.0
# OHCA Served is =  31.0
# 125 214 21
# OHCA Served is =  55.0
# OHCA Served is =  77.0
# 126 233 23
# OHCA Served is =  56.0
# OHCA Served is =  73.0
# 127 185 18
# OHCA Served is =  90.0
# OHCA Served is =  56.0
# 128 403 40
# OHCA Served is =  192.0
# OHCA Served is =  174.0
# 129 177 17
# OHCA Served is =  66.0
# OHCA Served is =  88.0
# 130 388 39
# OHCA Served is =  193.0
# OHCA Served is =  150.0
# 131 230 23
# OHCA Served is =  85.0
# OHCA Served is =  84.0
# 132 71 7
# OHCA Served is =  23.0
# OHCA Served is =  13.0
# 133 346 35
# OHCA Served is =  123.0
# OHCA Served is =  139.0
# 134 133 13
# OHCA Served is =  46.0
# OHCA Served is =  54.0
# 135 391 39
# OHCA Served is =  115.0
# OHCA Served is =  49.0
# 136 50 5
# OHCA Served is =  5.0
# OHCA Served is =  4.0
# 137 65 6
# OHCA Served is =  10.0
# OHCA Served is =  9.0
# 138 307 31
# OHCA Served is =  89.0
# OHCA Served is =  73.0
# 139 441 44
# OHCA Served is =  189.0
# OHCA Served is =  231.0
# 140 110 11
# OHCA Served is =  22.0
# OHCA Served is =  15.0
# 141 1428 144
# OHCA Served is =  661.0
# OHCA Served is =  713.0
# 142 216 21
# OHCA Served is =  76.0
# OHCA Served is =  97.0
# 143 327 33
# OHCA Served is =  126.0
# OHCA Served is =  116.0
# 144 916 92
# OHCA Served is =  425.0
# OHCA Served is =  435.0
# 145 412 41
# OHCA Served is =  None
# OHCA Served is =  122.0
# 146 268 27
# OHCA Served is =  68.0
# OHCA Served is =  59.0
# 147 313 31
# OHCA Served is =  125.0
# OHCA Served is =  158.0
# 148 181 18
# OHCA Served is =  77.0
# OHCA Served is =  42.0
# 149 264 26
# OHCA Served is =  102.0
# OHCA Served is =  98.0
# 150 932 94
# OHCA Served is =  398.0
# OHCA Served is =  496.0
# 151 640 64
# OHCA Served is =  301.0
# OHCA Served is =  308.0
# 152 797 80
# OHCA Served is =  379.0
# OHCA Served is =  380.0
# 153 18 1
# OHCA Served is =  0.0
# OHCA Served is =  0.0
# 154 368 37
# OHCA Served is =  140.0
# OHCA Served is =  206.0
# 155 605 61
# OHCA Served is =  285.0
# OHCA Served is =  98.0
# 156 1257 127
# OHCA Served is =  659.0
# OHCA Served is =  387.0
# 157 344 34
# OHCA Served is =  120.0
# OHCA Served is =  83.0
# 158 405 41
# OHCA Served is =  153.0
# OHCA Served is =  157.0
# 160 403 40
# OHCA Served is =  None
# OHCA Served is =  14.0
# 161 189 19
# OHCA Served is =  83.0
# OHCA Served is =  60.0
# 162 669 67
# OHCA Served is =  281.0
# OHCA Served is =  375.0
# 163 437 44
# OHCA Served is =  166.0
# OHCA Served is =  235.0
# 164 1147 116
# OHCA Served is =  574.0
# OHCA Served is =  548.0
# 165 156 15
# OHCA Served is =  66.0
# OHCA Served is =  69.0
# 166 138 13
# OHCA Served is =  23.0
# OHCA Served is =  49.0
# 167 203 20
# OHCA Served is =  83.0
# OHCA Served is =  57.0
# 168 430 43
# OHCA Served is =  165.0
# OHCA Served is =  224.0
# 169 547 55
# OHCA Served is =  139.0
# OHCA Served is =  104.0
# 170 375 37
# OHCA Served is =  171.0
# OHCA Served is =  161.0
# 171 129 13
# OHCA Served is =  69.0
# OHCA Served is =  39.0
# 172 353 35
# OHCA Served is =  149.0
# OHCA Served is =  147.0
# 173 371 37
# OHCA Served is =  167.0
# OHCA Served is =  146.0
# 175 308 31
# OHCA Served is =  128.0
# OHCA Served is =  150.0
# 176 253 25
# OHCA Served is =  85.0
# OHCA Served is =  38.0
# 177 436 44
# OHCA Served is =  None
# OHCA Served is =  137.0
# 178 380 38
# OHCA Served is =  48.0
# OHCA Served is =  52.0
# 179 1646 166
# OHCA Served is =  706.0
# OHCA Served is =  874.0
# 180 447 45
# OHCA Served is =  181.0
# OHCA Served is =  235.0
# 181 252 25
# OHCA Served is =  115.0
# OHCA Served is =  106.0
# 182 387 39
# OHCA Served is =  65.0
# OHCA Served is =  154.0
# 183 384 38
# OHCA Served is =  120.0
# OHCA Served is =  86.0
# 184 507 51
# OHCA Served is =  195.0
# OHCA Served is =  65.0
# 185 146 14
# OHCA Served is =  37.0
# OHCA Served is =  31.0
# 186 263 26
# OHCA Served is =  113.0
# OHCA Served is =  115.0
# 187 357 36
# OHCA Served is =  135.0
# OHCA Served is =  139.0
# 188 193 19
# OHCA Served is =  75.0
# OHCA Served is =  88.0
# 189 193 19
# OHCA Served is =  105.0
# OHCA Served is =  37.0
# 190 160 16
# OHCA Served is =  59.0
# OHCA Served is =  86.0
# 191 169 17
# OHCA Served is =  42.0
# OHCA Served is =  82.0
# 192 312 31
# OHCA Served is =  93.0
# OHCA Served is =  122.0
# 193 432 43
# OHCA Served is =  230.0
# OHCA Served is =  159.0
# 194 595 60
# OHCA Served is =  None
# OHCA Served is =  None
# 195 307 31
# OHCA Served is =  94.0
# OHCA Served is =  128.0
# 196 923 93
# OHCA Served is =  426.0
# OHCA Served is =  368.0
# 197 310 31
# OHCA Served is =  146.0
# OHCA Served is =  129.0
# 198 429 43
# OHCA Served is =  138.0
# OHCA Served is =  137.0
# 199 444 44
# OHCA Served is =  219.0
# OHCA Served is =  198.0
# 200 859 87
# OHCA Served is =  221.0
# OHCA Served is =  217.0
# 201 418 42
# OHCA Served is =  176.0
# OHCA Served is =  121.0
# 202 204 20
# OHCA Served is =  55.0
# OHCA Served is =  29.0
# 203 736 74
# OHCA Served is =  192.0
# OHCA Served is =  119.0
# 204 883 89
# OHCA Served is =  427.0
# OHCA Served is =  354.0
# 205 330 33
# OHCA Served is =  159.0
# OHCA Served is =  127.0
# 206 106 10
# OHCA Served is =  52.0
# OHCA Served is =  35.0
# 207 212 21
# OHCA Served is =  55.0
# OHCA Served is =  107.0
# 208 245 24
# OHCA Served is =  128.0
# OHCA Served is =  94.0
# 209 244 24
# OHCA Served is =  91.0
# OHCA Served is =  122.0
# 210 406 41
# OHCA Served is =  183.0
# OHCA Served is =  133.0
# 211 31 3
# OHCA Served is =  0.0
# 212 307 31
# OHCA Served is =  144.0
# OHCA Served is =  138.0
# 213 647 65
# OHCA Served is =  320.0
# OHCA Served is =  283.0
# 214 407 41
# OHCA Served is =  193.0
# OHCA Served is =  178.0
# 215 633 64
# OHCA Served is =  297.0
# OHCA Served is =  284.0
# 216 270 27
# OHCA Served is =  34.0
# 217 149 15
# OHCA Served is =  24.0
# OHCA Served is =  33.0
# 218 150 15
# OHCA Served is =  17.0
# OHCA Served is =  22.0
# 219 312 31
# OHCA Served is =  103.0
# OHCA Served is =  99.0
# 220 343 34
# OHCA Served is =  None
# OHCA Served is =  None
# 221 70 7
# OHCA Served is =  None
# 222 370 37
# OHCA Served is =  141.0
# OHCA Served is =  166.0
# 223 827 83
# OHCA Served is =  None
# OHCA Served is =  83.0
# 224 55 5
# OHCA Served is =  4.0
# OHCA Served is =  6.0
# 225 36 3
# OHCA Served is =  13.0
# OHCA Served is =  7.0
# 226 153 15
# OHCA Served is =  54.0
# OHCA Served is =  56.0
# 227 309 31
# OHCA Served is =  115.0
# OHCA Served is =  106.0
# 228 629 63
# OHCA Served is =  75.0
# OHCA Served is =  175.0
# 229 173 17
# OHCA Served is =  31.0
# OHCA Served is =  34.0
# 230 293 29
# OHCA Served is =  163.0
# OHCA Served is =  62.0
# 232 285 28
# OHCA Served is =  140.0
# OHCA Served is =  113.0
# 233 211 21
# OHCA Served is =  105.0
# OHCA Served is =  82.0
# 234 291 29
# OHCA Served is =  128.0
# OHCA Served is =  139.0
# 235 311 31
# OHCA Served is =  143.0
# OHCA Served is =  90.0
# 236 600 60
# OHCA Served is =  285.0
# OHCA Served is =  299.0
# 237 103 10
# OHCA Served is =  None
# OHCA Served is =  32.0
# 238 145 14
# OHCA Served is =  47.0
# OHCA Served is =  56.0
# 240 206 20
# OHCA Served is =  74.0
# OHCA Served is =  87.0
# 241 209 21
# OHCA Served is =  64.0
# OHCA Served is =  62.0
# 242 239 24
# OHCA Served is =  108.0
# OHCA Served is =  99.0
# 243 708 71
# OHCA Served is =  247.0
# OHCA Served is =  413.0
# 244 306 30
# OHCA Served is =  106.0
# OHCA Served is =  118.0
# 245 290 29
# OHCA Served is =  36.0
# OHCA Served is =  128.0
# 246 192 19
# OHCA Served is =  76.0
# OHCA Served is =  84.0
# 247 196 19
# OHCA Served is =  92.0
# OHCA Served is =  75.0
# 248 179 18
# OHCA Served is =  74.0
# OHCA Served is =  72.0
# 249 664 67
# OHCA Served is =  264.0
# OHCA Served is =  309.0
# 250 400 40
# OHCA Served is =  206.0
# OHCA Served is =  None
# 251 465 47
# OHCA Served is =  103.0
# OHCA Served is =  104.0
# 252 192 19
# OHCA Served is =  53.0
# OHCA Served is =  59.0
# 253 242 24
# OHCA Served is =  51.0
# OHCA Served is =  78.0
# 254 369 37
# OHCA Served is =  118.0
# OHCA Served is =  54.0
# 255 196 19
# OHCA Served is =  60.0
# OHCA Served is =  22.0
# 256 225 22
# OHCA Served is =  95.0
# OHCA Served is =  87.0
# 257 503 50
# OHCA Served is =  165.0
# OHCA Served is =  278.0
# 258 154 15
# OHCA Served is =  None
# 260 446 45
# OHCA Served is =  200.0
# OHCA Served is =  218.0
# 261 429 43
# OHCA Served is =  143.0
# OHCA Served is =  223.0
# 262 207 20
# OHCA Served is =  38.0
# OHCA Served is =  None
# 263 511 51
# OHCA Served is =  112.0
# OHCA Served is =  239.0
# 264 301 30
# OHCA Served is =  98.0
# OHCA Served is =  133.0
# 265 138 13
# OHCA Served is =  44.0
# OHCA Served is =  45.0
# 266 495 50
# OHCA Served is =  46.0
# OHCA Served is =  None
# 267 244 24
# OHCA Served is =  67.0
# OHCA Served is =  103.0
# 268 248 25
# OHCA Served is =  87.0
# OHCA Served is =  84.0
# 269 602 60
# OHCA Served is =  27.0
# OHCA Served is =  97.0
# 270 126 12
# OHCA Served is =  10.0
# OHCA Served is =  21.0
# 271 147 14
# OHCA Served is =  35.0
# OHCA Served is =  43.0
# 272 112 11
# OHCA Served is =  None
# 273 1960 198
# OHCA Served is =  None
# OHCA Served is =  None
# 274 71 7
# OHCA Served is =  16.0
# OHCA Served is =  10.0
# 275 49 4
# OHCA Served is =  6.0
# OHCA Served is =  3.0
# 276 100 10
# OHCA Served is =  26.0
# OHCA Served is =  18.0
# 277 93 9
# OHCA Served is =  32.0
# OHCA Served is =  48.0
# 278 72 7
# OHCA Served is =  8.0
# OHCA Served is =  8.0
# 279 35 3
# OHCA Served is =  4.0
# OHCA Served is =  3.0
# 280 52 5
# OHCA Served is =  None
# 281 111 11
# OHCA Served is =  None
# OHCA Served is =  23.0
# 282 237 24
# OHCA Served is =  None
# OHCA Served is =  None
# 285 137 13
# OHCA Served is =  None
# 286 274 27
# OHCA Served is =  None
# OHCA Served is =  None
# 288 84 8
# OHCA Served is =  23.0
# OHCA Served is =  18.0
# 289 480 48
# OHCA Served is =  175.0
# OHCA Served is =  43.0
# 290 116 11
# OHCA Served is =  45.0
# OHCA Served is =  41.0
# 291 623 63
# OHCA Served is =  31.0
# OHCA Served is =  13.0
# 292 48 4
# OHCA Served is =  19.0
# OHCA Served is =  21.0
# 293 344 34
# OHCA Served is =  154.0
# OHCA Served is =  135.0
# 294 1169 118
# OHCA Served is =  566.0
# OHCA Served is =  569.0
# 295 33 3
# OHCA Served is =  1.0
# OHCA Served is =  4.0
# 296 184 18
# OHCA Served is =  None
# OHCA Served is =  16.0
# 297 386 39
# OHCA Served is =  158.0
# OHCA Served is =  115.0
# 298 350 35
# OHCA Served is =  118.0
# OHCA Served is =  149.0
# 299 480 48
# OHCA Served is =  212.0
# OHCA Served is =  201.0
# 300 1966 199
# OHCA Served is =  159.0
# OHCA Served is =  289.0
# 302 491 49
# OHCA Served is =  246.0
# OHCA Served is =  203.0
# 303 193 19
# OHCA Served is =  70.0
# OHCA Served is =  54.0
# 306 422 42
# OHCA Served is =  139.0
# OHCA Served is =  209.0
# 307 323 32
# OHCA Served is =  145.0
# OHCA Served is =  157.0
# 308 443 44
# OHCA Served is =  206.0
# OHCA Served is =  88.0
# 309 298 30
# OHCA Served is =  103.0
# OHCA Served is =  98.0
# 310 306 30
# OHCA Served is =  43.0
# OHCA Served is =  None
# 311 80 8
# OHCA Served is =  17.0
# OHCA Served is =  10.0
# 312 789 79
# OHCA Served is =  335.0
# OHCA Served is =  364.0
# 313 257 26
# OHCA Served is =  105.0
# OHCA Served is =  114.0
# 314 312 31
# OHCA Served is =  64.0
# OHCA Served is =  47.0
# 315 134 13
# OHCA Served is =  36.0
# OHCA Served is =  51.0
# 316 174 17
# OHCA Served is =  52.0
# OHCA Served is =  59.0
# 318 198 20
# OHCA Served is =  54.0
# OHCA Served is =  71.0
# 319 95 9
# OHCA Served is =  2.0
# OHCA Served is =  5.0
# 320 330 33
# OHCA Served is =  None
# 321 335 33
# OHCA Served is =  134.0
# OHCA Served is =  82.0
# 322 167 16
# OHCA Served is =  21.0
# OHCA Served is =  65.0
# 324 278 28
# OHCA Served is =  None
# OHCA Served is =  86.0
# 325 923 93
# OHCA Served is =  None
# OHCA Served is =  None
# 326 1414 143
# OHCA Served is =  None
# OHCA Served is =  None
# 327 115 11
# OHCA Served is =  18.0
# OHCA Served is =  None
# 328 745 75
# OHCA Served is =  287.0
# OHCA Served is =  235.0
# 329 216 21
# OHCA Served is =  78.0
# OHCA Served is =  103.0
# 330 178 18
# OHCA Served is =  99.0
# OHCA Served is =  64.0
# 331 597 60
# OHCA Served is =  254.0
# OHCA Served is =  247.0
# 332 26 2
# OHCA Served is =  0.0
# OHCA Served is =  2.0
# Time is --- 90.73087239265442 seconds ---
# Wall time: 1min 30s

# %%
# New computing time
# Time is --- 90.73087239265442 seconds ---
# Wall time: 1min 30s

# %%
print('The final Kmeans-MCLP AED result is in this dataframe below: ')
ALL_AED
# Out:
# The final Kmeans-MCLP AED result is in this dataframe below:
#        LatAED     LongAED
# 0    1.293037  103.837773
# 4    1.294161  103.838058
# 30   1.294685  103.841406
# 85   1.293294  103.840845
# 89   1.291955  103.839607
# ..        ...         ...
# 223  1.354409  103.846451
# 244  1.353233  103.847712
# 254  1.354723  103.844875
# 0    1.266342  103.622595
# 51   1.277594  103.637965
#
# [8257 rows x 2 columns]

# %%
ALL_AED.to_csv('MCLP-MultiArea-KMeans-AED-Solution.csv')
plt.scatter(
   ALL_AED['LatAED'], 
   ALL_AED['LongAED'],s=3
)

# %%
######################################################################################################
#Metrics
######################################################################################################

# %%
def totalCoverage(ohca_df, aed_df, MAX_DIST_METERS = 100):
    def ClosestAED(r):
        # Cartesian Distance: square root of (x2-x1)^2 + (y2-y1)^2
        distances = ((r['LatOHCA']-aed_df['LatAED'])**2 + (r['LongOHCA']-aed_df['LongAED'])**2)**0.5

        # AED with minimum Distance from the OHCA
        closestAEDId = distances[distances == distances.min()].index.to_list()[0]
        return aed_df.loc[closestAEDId, ['LatAED', 'LongAED']]

    cp_ohca = ohca_df.copy()
    cp_ohca[['ClosestAEDLatitude', 'ClosestAEDLongtitude']] = cp_ohca.apply(ClosestAED, axis=1)
    
    def haversine_np(lat1, lon1, lat2, lon2):
        lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
        dlon = lon2 - lon1
        dlat = lat2 - lat1

        a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
        c = 2 * np.arcsin(np.sqrt(a))
        km = 6367 * c
        return km * 1000
    
    cp_ohca['dist_nearest_AED'] = haversine_np(cp_ohca['LatOHCA'], cp_ohca['LongOHCA'],
                                               cp_ohca['ClosestAEDLatitude'], cp_ohca['ClosestAEDLongtitude'])
    # distance to nearest AED (in metres) is recorded for each OHCA
    
    cp_ohca.loc[cp_ohca['dist_nearest_AED'] <= 100, 'isCovered'] = 'covered'
    cp_ohca.loc[cp_ohca['dist_nearest_AED'] > 100,'isCovered'] = 'uncovered'
    # each OHCA having an AED within 100m has isCovered = 'covered', otherwise 'uncovered'
    #print(cp_ohca)
    
    
    within_100m  = sum(cp_ohca['isCovered'] == 'covered')
    outside_100m = len(cp_ohca) - within_100m
    total_coverage_within_100m = within_100m / (within_100m + outside_100m)
    print("total coverage = ", total_coverage_within_100m)
    
    return total_coverage_within_100m

def partial_coverage(ohca_df, aed_df, ALPHA = 0.05):
    def ClosestAED(r):
        # Cartesian Distance: square root of (x2-x1)^2 + (y2-y1)^2
        distances = ((r['LatOHCA']-aed_df['LatAED'])**2 + (r['LongOHCA']-aed_df['LongAED'])**2)**0.5

        # AED with minimum Distance from the OHCA
        closestAEDId = distances[distances == distances.min()].index.to_list()[0]
        return aed_df.loc[closestAEDId, ['LatAED', 'LongAED']]

    cp_ohca = ohca_df.copy()
    cp_ohca[['ClosestAEDLatitude', 'ClosestAEDLongtitude']] = cp_ohca.apply(ClosestAED, axis=1)
    
    def haversine_np(lat1, lon1, lat2, lon2):
        lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
        dlon = lon2 - lon1
        dlat = lat2 - lat1

        a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
        c = 2 * np.arcsin(np.sqrt(a))
        km = 6367 * c
        return km * 1000

    cp_ohca['dist_nearest_AED'] = haversine_np(cp_ohca['LatOHCA'], cp_ohca['LongOHCA'],
                                               cp_ohca['ClosestAEDLatitude'], cp_ohca['ClosestAEDLongtitude'])
    # distance to nearest AED (in metres) is recorded for each OHCA
    
    cp_ohca.loc[cp_ohca['dist_nearest_AED'] <= 20,'p_ij_coverage'] = 1.0
    cp_ohca.loc[cp_ohca['dist_nearest_AED'] >= 100,'p_ij_coverage'] = 0.0
    cp_ohca.loc[(cp_ohca['dist_nearest_AED'] < 100) & (cp_ohca['dist_nearest_AED'] > 20),
                'p_ij_coverage'] = np.exp(- ALPHA * (cp_ohca['dist_nearest_AED'] - 20))
    # p_ij of each OHCA calulated
    # print(cp_ohca)
    
    return cp_ohca['p_ij_coverage'].mean()

def expectedsurvival(OHCA,AED):
    prob = 0
    for i in range(len(OHCA)):
        survival = haversine_vector((OHCA.LatOHCA[i], OHCA.LongOHCA[i]), list(zip(AED.LatAED, AED.LongAED)), Unit.METERS, comb=True).T[0]
        survival = survival/(6.15*1000/60)*2
        survival = [p if np.isnan(p) == False else 0 for p in survival]
        survival = [1 if p<=1 and p != 0 else p for p in survival]
        survival = [p if p<20 else 0 for p in survival]
        survival = [p if p==0 or p == 1 else ((p**-0.584)*0.549) for p in survival]
        prob += max(survival)
    expectedSurvival = prob/len(OHCA)
    return(expectedSurvival)

# %%
def average_distance(ohca_df, aed_df):
    def ClosestAED(r):
        # Cartesian Distance: square root of (x2-x1)^2 + (y2-y1)^2
        distances = ((r['LatOHCA']-aed_df['LatAED'])**2 + (r['LongOHCA']-aed_df['LongAED'])**2)**0.5

        # AED with minimum Distance from the OHCA
        closestAEDId = distances[distances == distances.min()].index.to_list()[0]
        return aed_df.loc[closestAEDId, ['LatAED', 'LongAED']]

    cp_ohca = ohca_df.copy()
    cp_ohca[['ClosestAEDLatitude', 'ClosestAEDLongtitude']] = cp_ohca.apply(ClosestAED, axis=1)
    
    def haversine_np(lat1, lon1, lat2, lon2):
        lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])
        dlon = lon2 - lon1
        dlat = lat2 - lat1

        a = np.sin(dlat/2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2.0)**2
        c = 2 * np.arcsin(np.sqrt(a))
        km = 6367 * c
        return km * 1000

    cp_ohca['dist_nearest_AED'] = haversine_np(cp_ohca['LatOHCA'], cp_ohca['LongOHCA'],
                                               cp_ohca['ClosestAEDLatitude'], cp_ohca['ClosestAEDLongtitude'])
    # distance to nearest AED (in metres) is recorded for each OHCA
    
    
    return cp_ohca['dist_nearest_AED'].mean()

# %%
AED_Chosen_All_MCLP=ALL_AED.reset_index(drop=True)
#AED_Chosen_All_MCLP = pd.read_csv("MCLP_SingleBest_Output.csv",index_col=0)
#total coverage 
MCLP_TC = totalCoverage(OHCA,AED_Chosen_All_MCLP,100)
print("MCLP total coverage is : ", MCLP_TC)
#partial coverage
MCLP_PC = partial_coverage(OHCA,AED_Chosen_All_MCLP)
# print("MCLP partial coverage is : ", MCLP_PC)
# #expected survival
MCLP_ES = expectedsurvival(OHCA,AED_Chosen_All_MCLP)
print("MCLP expected survival is : ", MCLP_ES)
#average distance to nearest AED
MCLP_AD = average_distance(OHCA, AED_Chosen_All_MCLP)
print("MCLP average distance is : ", MCLP_AD)
# Out:
# total coverage =  0.6616681215446647
# MCLP total coverage is :  0.6616681215446647
# MCLP expected survival is :  0.48585397097264404
# MCLP average distance is :  163.57964207632915

# %%
print("MCLP partial coverage is : ", MCLP_PC)
# Out:
# MCLP partial coverage is :  0.14763584949013503
